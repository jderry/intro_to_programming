# %% [markdown]
# content taken from $\textit{Computational Mathematics with SageMath}$

# %%
(1 + 2 * (3 + 5)) * 2 # note that we can annotate computation cells using python comments

# %%
2^3 #

# %%
20/6

# %%
QQ(1.5) # QQ() returns a value in the rational field

# %%
2^1000 # there is no limit to the size of integers or rational numbers,
# except due to available memory on your computer

# %%
20./6 # to obtain a numerical approximation, one simply writes one of the numbers with a decimal point

# %%
numerical_approx(2^1000) # we can also use the numerical_approx() function

# %%
numerical_approx(2^1000, digits=60)

# %%
divmod(20, 6) # returns tuple of quotient and remainder

# %%
factor(2^(2^5)+1) # we can decompose an integer into prime factors.

# %% [markdown]
# Fermat had conjectured that all integers $2^{2^n} +1$ are prime. The above example is the smallest counterexample.

# %%
tan(pi/3) # the usual elementary functions and constants are available. computations are exact.
# Out:
# sqrt(3)

# %%
exp(2 * I * pi) # the exponential function

# %% [markdown]
# exp(x) = $e^{x}$. hence, the expression in the last computation cell is $e^{2 * I * \pi}$

# %%
''' the semicolon (;) is used in Python to end a statement
    we don't normally see it because best stylistic practice in Python
    is to write only one statement to a line, in which case
    Guido van Rossum believed the semicolon is superfluous
    and so isn't needed or used.
'''
y = 3 * (1 + 2) + 1; y
# here, we use it to concatenate an assignment statement
# with an invocation statement so that on one line we create and instantiate
# a variable, then print the value assigned to the variable.

# %%
''' Python is a general programming language.
    In SymPy and SageMath, Python is used in a CAS (Computer Algebra System).
    As a result, the user of SymPy and SageMath has to distinguish between
    "programmer's variables" (like the one in the last computation cell)
    and "mathematician's symbolic variables"...
'''
z = SR.var('z')
expr = 2 * z + 3; expr

# %%
plot(sin(2*x), x, -pi, pi)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x, y = SR.var('x y')
plot3d(sin(pi*sqrt(x^2 + y^2))/sqrt(x^2+y^2), (x,-5,5), (y,-5,5))
# Out:
# Graphics3d Object
