# %% [markdown]
# ![water_heater_calc_hp.jpg](attachment:water_heater_calc_hp.jpg)

# %% [markdown]
# ![water_heater_example.jpg](attachment:water_heater_example.jpg)
