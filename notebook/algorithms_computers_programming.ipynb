# %% [markdown]
# # programming: a little background

# %% [raw]
# computer science, known in other indo-european languages as 'informatik' or a cognate thereof, in its broadest terms is about processing data and information. its roots lie in mathematics; and many computer scientists might still agree that it is still math. dutch-born edsger dijkstra, a giant in the field who occupied the schlumberger centennial chair in computer sciences here at UT-austin from 1984-1999, is reported to have said, 'computer science is no more about computers than astronomy is about telescopes.'

# %% [raw]
# what could he have meant?

# %% [raw]
# the answer lies in the history of mathematics. today it is commonplace to think of words like 'algorithm' and 'computer' in terms of electronic computers; but those words pre-date the modern computer age, as does our modern meaning of algorithm. later we will go over a more rigorous definition of 'algorithm'; but for now, let's say that it means a way of solving a problem in a finite number of steps.

# %% [markdown]
# ## 0.1 history of the algorithm

# %% [raw]
# the known oldest algorithm that is still in use is euclid's algorithm for finding the greatest common divisor (or g.c.d.). euclid described this algorithm in the 13 books that make up his 'elements', which dates back to about 300 b.c.e.

# %% [raw]
# briefly, euclid's g.c.d algorithm finds the g.c.d of two positive integers by taking the remainder in the successive division of integers:
# 'In its simplest form, Euclid's algorithm starts with a pair of positive integers, and forms a new pair that consists of the smaller number and the difference between the larger and smaller numbers. The process repeats until the numbers in the pair are equal. That number then is the greatest common divisor of the original pair of integers.'
# -- en.wikipedia.org, 'Euclidean algorithm'

# %%
from IPython.display import IFrame
IFrame('https://upload.wikimedia.org/wikipedia/commons/d/d3/Euclid_flowchart_1.png', 400, 600)
# Out:
#         <iframe
#             width="400"
#             height="600"
#             src="https://upload.wikimedia.org/wikipedia/commons/d/d3/Euclid_flowchart_1.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [raw]
# above: euclid's g.c.d. algorithm rendered as a flowchart

# %% [raw]
# as an algorithm solves a problem in a finite number of steps, the best way to understand some algorithms is to work through them by pencil and hand. to understand the algorithm and how it works, we shall work through euclid's algorithm in class.

# %% [raw]
# the achievements of classical greek civilization influenced all civilizations that made contact with it. the ummah, or islamic civilizations that include both muslims and non-muslims living in the ummah, is no exception. one of the greatest mathematicians in history is the persian al-khwārizmī, who in the 9th century codified the rules of algebra and a systematic means of doing arithmetic.

# %%
from IPython.display import IFrame
IFrame('https://en.wikipedia.org/wiki/Al-Khw%C4%81rizm%C4%AB', width=800, height=650)
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="https://en.wikipedia.org/wiki/Al-Khw%C4%81rizm%C4%AB"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [raw]
# no doubt al-khwārizmī was aware of euclid's work. i am, however, unqualified to give an opinion of the extent to which euclid's g.c.d. algorithm might have influenced al-khwārizmī's thinking as he systemized the means of doing arithmetic that in the west became known as 'algorism' and from which the word 'algorithm' is derived. 'algorithm' and 'algorism' are latinized forms of al-khwārizmī's name.

# %%
from IPython.display import IFrame
IFrame('http://en.wikipedia.org/wiki/Algorism', width=800, height=650)
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="http://en.wikipedia.org/wiki/Algorism"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame
IFrame('https://en.wikipedia.org/wiki/Algorithm', width=800, height=650)
# Out:
#         <iframe
#             width="800"
#             height="650"
#             src="https://en.wikipedia.org/wiki/Algorithm"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## 0.2 history of the computer

# %% [raw]
# the first known written reference to the word 'computer' dates to 1613. for hundreds of years it referred to a person; specifically, to 'one who computes'. the first known example of organized human computing took place in the 18th century, and was carried out by scientists. as the computational demands of math, science, and engineering grew, so did the need for computers.

# %% [raw]
# the title 'computer' came to refer to a clerical position, of less pay and lower status than secretary. departments hired staffs of computers, while labs might depend on students, both graduate and undergraduate, to serve as computers. a computer staff might be given sheets with initial quantities, and detailed instructions, or algorithms, on how to process those quantities into the desired output.

# %%
from IPython.display import IFrame
IFrame('https://en.wikipedia.org/wiki/Human_computer', width=800, height=590)
# Out:
#         <iframe
#             width="800"
#             height="590"
#             src="https://en.wikipedia.org/wiki/Human_computer"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [raw]
# so ubiquitous and so universal were human computers before electronic computers replaced them, that the early pioneers of computer science often used them as examples in thought experiments -- as in alan turing's quote above: "The human computer is supposed to be following fixed rules; he has no authority to deviate from them in any detail."

# %% [raw]
# among the most famous staffs of computers was the collection of women who came to be known as 'the harvard computers', or the more sexist moniker, 'pickering's harem.'

# %%
from IPython.display import IFrame
IFrame('https://en.wikipedia.org/wiki/Harvard_Computers', width=800, height=850)
# Out:
#         <iframe
#             width="800"
#             height="850"
#             src="https://en.wikipedia.org/wiki/Harvard_Computers"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [raw]
# dr. pickering lost his patience with the errors due to carelessness of his male computers, insisting that his housekeeper could do a better job. he fired the men, made his housekeeper the head computer, and gave her leave to hire and fire her subordinates. the computer staff became all women, and their work was impeccible. as the reputation of the harvard computers grew, more organizations opted to hire all-female computer staffs, as doing so not only improved the quality of output, it also saved money -- women worked for about half the pay of men.

# %% [markdown]
# ![1%20HPfKUlWmUsXxC1LWhTV5Kw.jpeg](attachment:1%20HPfKUlWmUsXxC1LWhTV5Kw.jpeg)

# %% [markdown]
# ### being a human computer means doing long, tedious, boring work by eye, hand, and brain that electronic computers can do. one might say that, in learning how to program, we are moving away from being computers to putting electronic computers to best use, resulting in greater speed and accuracy in our workflow.

# %% [markdown]
# ## 0.3 modern definition of algorithm

# %% [raw]
# another giant in the field of computer science is donald knuth. as young as the field is, it has one work that is universally considered its magnum opus, the classic; and that is knuth's multi-volume work 'the art of computer programming'. in volume one, 'fundamental algorithms', knuth jumps right into the subject, starting chapter one of his magnum opus by discussing al-khwārizmī (paragraph two) and euclid's g.c.d. algorithm (paragraph five). after analyzing euclid's algorithm, knuth expands upon the modern meaning of 'algorithm':

# %% [raw]
# 'besides merely being a finite set of rules which gives a sequence of operations for solving a specific type of problem, an algorithm has five important features:

# %% [raw]
# 1) finiteness. an algorithm must always terminate after a finite number of steps...

# %% [raw]
# 2) definiteness. each step of an algorithm must be precisely defined; the actions to be carried out must be rigorously and unambiguously specified for each case...

# %% [raw]
# 3) input. an algorithm has zero or more inputs, i.e., quantities which are given to it initially before the algorithm begins...

# %% [raw]
# 4) output. an algorithm has one or more outputs, i.e., quantities which have a specified relation to the inputs...

# %% [raw]
# 5) effectiveness. an algorithm is also generally expected to be effective. this means that all of the operations to be performed in the algorithm must be sufficiently basic that they can in principle be done exactly and in a finite length of time by a man using pencil and paper.

# %% [markdown]
# ## 0.4 my take on what dijikstra meant

# %% [raw]
# 'computer science is no more about computers than astronomy is about telescopes'
# -- edsger dijkstra

# %% [raw]
# computer science is the study of the processing of data and information, regardless of what the processor is. it could be a human or a machine, analog or digital, hardware or wetware. by extension, computer science concerns itself with the storage, representation, communication, and retrieval of data and information. and as far as processing data and information goes, computer science concerns itself with the analyses of algorithms, their efficiency and complexity.

# %% [raw]
# and the computer is one tool -- arguably the most important one -- that allows the computer scientist to study all of this.

# %% [markdown]
# ## 0.5 and what does all this mean to us?

# %% [raw]
# in this class, our focus will be on programming. it will be on reading and writing code that, when run, helps researchers improve their workflow. and to ensure that beginning programmers start off with skills and knowledge that will help them throughout their careers, we will look at program design methodology, error-trapping and program correctness; and at analyzing the time complexity of algorithms and profiling code. while some of this has a theoretical feel to it, considering all of it is meant to help avoid the pitfalls that beginning programmers stumble into, and to make all programmers as productive as possible.
