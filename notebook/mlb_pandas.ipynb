# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
mlb = pd.read_csv('../datafile/MLB.txt', sep='\t')
mlb
# Out:
#                  Name Team        Position  Height  Weight    Age
# 0       Adam Donachie  BAL         Catcher     NaN   180.0  22.99
# 1           Paul Bako  BAL         Catcher    74.0   215.0  34.69
# 2     Ramon Hernandez  BAL         Catcher    72.0   210.0  30.78
# 3        Kevin Millar  BAL   First Baseman    72.0   210.0  35.43
# 4         Chris Gomez  BAL   First Baseman    73.0   188.0  35.71
# ...               ...  ...             ...     ...     ...    ...
# 1029    Brad Thompson  STL  Relief Pitcher    73.0   190.0  25.08
# 1030    Tyler Johnson  STL  Relief Pitcher    74.0   180.0  25.73
# 1031   Chris Narveson  STL  Relief Pitcher    75.0   205.0  25.19
# 1032    Randy Keisler  STL  Relief Pitcher    75.0   190.0  31.01
# 1033      Josh Kinney  STL  Relief Pitcher    73.0   195.0  27.92
#
# [1034 rows x 6 columns]

# %%
mlb.columns.values.tolist()
# Out:
# ['Name', 'Team', 'Position', 'Height', 'Weight', 'Age']

# %%
mlb.describe()
# Out:
#             Height       Weight          Age
# count  1033.000000  1033.000000  1034.000000
# mean     73.696999   201.689255    28.736712
# std       2.306916    20.991491     4.320310
# min      67.000000   150.000000    20.900000
# 25%      72.000000   187.000000    25.440000
# 50%      74.000000   200.000000    27.925000
# 75%      75.000000   215.000000    31.232500
# max      83.000000   290.000000    48.520000

# %%
mlb.median(numeric_only=True)
# Out:
# Height     74.000
# Weight    200.000
# Age        27.925
# dtype: float64

# %%
mlb.corr(numeric_only=True)
# Out:
#           Height    Weight       Age
# Height  1.000000  0.532297 -0.073565
# Weight  0.532297  1.000000  0.158282
# Age    -0.073565  0.158282  1.000000

# %%
mlb.cov(numeric_only=True)
# Out:
#            Height      Weight        Age
# Height   5.321861   25.781663  -0.732915
# Weight  25.781663  440.642685  14.361168
# Age     -0.732915   14.361168  18.665079

# %%
mlb.plot()
# Out:
# <Axes: >

# %%
mlb.boxplot()
# Out:
# <Axes: >

# %%
mlb.plot(kind='scatter', x='Height', y='Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
mlb.hist(bins=50)
# Out:
# array([[<Axes: title={'center': 'Height'}>,
#         <Axes: title={'center': 'Weight'}>],
#        [<Axes: title={'center': 'Age'}>, <Axes: >]], dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(mlb, diagonal='kde')
# Out:
# array([[<Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Age', ylabel='Height'>],
#        [<Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Age', ylabel='Weight'>],
#        [<Axes: xlabel='Height', ylabel='Age'>,
#         <Axes: xlabel='Weight', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.boxplot(data=mlb)
# Out:
# <Axes: >

# %%
sns.lmplot(x='Height', y='Weight', data=mlb)

# %%
sns.violinplot(x='Height', y='Weight', data=mlb)
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>
